# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('E:\ML\cbb.csv', sep=',', engine='python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                 TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...  ...  ..  ..    ...    ...      ...    ...    ...   ...
# 1752       Texas A&M  SEC  35  22  111.2   94.7   0.8640   51.4   46.9  19.2
# 1753             LSU  SEC  35  28  117.9   96.6   0.9081   51.2   49.9  17.9
# 1754       Tennessee  SEC  36  31  122.8   95.2   0.9488   55.3   48.1  15.8
# 1755         Gonzaga  WCC  35  27  117.4   94.5   0.9238   55.2   44.8  17.1
# 1756         Gonzaga  WCC  37  32  117.2   94.9   0.9192   57.0   47.1  16.1
#
#       ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0     ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1     ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2     ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3     ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4     ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
# ...   ...   ...   ...   ...   ...   ...    ...   ...         ...   ...   ...
# 1752  ...  27.6  52.5  45.7  32.9  32.6   70.3   1.9         S16   7.0  2018
# 1753  ...  33.1  52.9  49.4  31.9  33.7   71.2   7.3         S16   3.0  2019
# 1754  ...  34.9  55.4  44.7  36.7  35.4   68.8   9.9         S16   2.0  2019
# 1755  ...  28.1  54.3  44.4  37.8  30.3   68.2   2.1         S16  11.0  2016
# 1756  ...  29.1  58.2  44.1  36.8  35.0   70.5   4.9         S16   4.0  2018
#
# [1757 rows x 24 columns]

# %%
print(data)
# Out:
#                 TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...  ...  ..  ..    ...    ...      ...    ...    ...   ...
# 1752       Texas A&M  SEC  35  22  111.2   94.7   0.8640   51.4   46.9  19.2
# 1753             LSU  SEC  35  28  117.9   96.6   0.9081   51.2   49.9  17.9
# 1754       Tennessee  SEC  36  31  122.8   95.2   0.9488   55.3   48.1  15.8
# 1755         Gonzaga  WCC  35  27  117.4   94.5   0.9238   55.2   44.8  17.1
# 1756         Gonzaga  WCC  37  32  117.2   94.9   0.9192   57.0   47.1  16.1
#
#       ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0     ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1     ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2     ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3     ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4     ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
# ...   ...   ...   ...   ...   ...   ...    ...   ...         ...   ...   ...
# 1752  ...  27.6  52.5  45.7  32.9  32.6   70.3   1.9         S16   7.0  2018
# 1753  ...  33.1  52.9  49.4  31.9  33.7   71.2   7.3         S16   3.0  2019
# 1754  ...  34.9  55.4  44.7  36.7  35.4   68.8   9.9         S16   2.0  2019
# 1755  ...  28.1  54.3  44.4  37.8  30.3   68.2   2.1         S16  11.0  2016
# 1756  ...  29.1  58.2  44.1  36.8  35.0   70.5   4.9         S16   4.0  2018
#
# [1757 rows x 24 columns]

# %%
data.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3  ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4  ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
#
# [5 rows x 24 columns]

# %%
data.tail()
# Out:
#            TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 1752  Texas A&M  SEC  35  22  111.2   94.7   0.8640   51.4   46.9  19.2  ...
# 1753        LSU  SEC  35  28  117.9   96.6   0.9081   51.2   49.9  17.9  ...
# 1754  Tennessee  SEC  36  31  122.8   95.2   0.9488   55.3   48.1  15.8  ...
# 1755    Gonzaga  WCC  35  27  117.4   94.5   0.9238   55.2   44.8  17.1  ...
# 1756    Gonzaga  WCC  37  32  117.2   94.9   0.9192   57.0   47.1  16.1  ...
#
#       FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T  WAB  POSTSEASON  SEED  YEAR
# 1752  27.6  52.5  45.7  32.9  32.6   70.3  1.9         S16   7.0  2018
# 1753  33.1  52.9  49.4  31.9  33.7   71.2  7.3         S16   3.0  2019
# 1754  34.9  55.4  44.7  36.7  35.4   68.8  9.9         S16   2.0  2019
# 1755  28.1  54.3  44.4  37.8  30.3   68.2  2.1         S16  11.0  2016
# 1756  29.1  58.2  44.1  36.8  35.0   70.5  4.9         S16   4.0  2018
#
# [5 rows x 24 columns]

# %%
data.shape
# Out:
# (1757, 24)

# %%
#название столбцов:
data.columns
# Out:
# Index(['TEAM', 'CONF', 'G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
#        'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
#        '3P_D', 'ADJ_T', 'WAB', 'POSTSEASON', 'SEED', 'YEAR'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1757, step=1)

# %%
data.describe()
# Out:
#                  G            W        ADJOE        ADJDE      BARTHAG  \
# count  1757.000000  1757.000000  1757.000000  1757.000000  1757.000000
# mean     31.523051    16.513375   103.542402   103.542459     0.493398
# std       2.602819     6.545571     7.304975     6.472676     0.255291
# min      24.000000     0.000000    76.700000    84.000000     0.007700
# 25%      30.000000    12.000000    98.600000    98.900000     0.283700
# 50%      31.000000    16.000000   103.100000   103.800000     0.474000
# 75%      33.000000    21.000000   108.100000   108.000000     0.710600
# max      40.000000    38.000000   129.100000   124.000000     0.984200
#
#              EFG_O        EFG_D          TOR         TORD          ORB  ...  \
# count  1757.000000  1757.000000  1757.000000  1757.000000  1757.000000  ...
# mean     50.120489    50.312806    18.591804    18.521286    29.277120  ...
# std       3.130430     2.859604     1.991637     2.108968     4.101782  ...
# min      39.400000    39.600000    12.400000    10.200000    15.000000  ...
# 25%      48.100000    48.400000    17.200000    17.100000    26.600000  ...
# 50%      50.000000    50.300000    18.500000    18.500000    29.400000  ...
# 75%      52.100000    52.300000    19.800000    19.900000    31.900000  ...
# max      59.800000    59.500000    26.100000    28.000000    42.100000  ...
#
#                FTR         FTRD         2P_O         2P_D         3P_O  \
# count  1757.000000  1757.000000  1757.000000  1757.000000  1757.000000
# mean     35.097894    35.373307    49.135970    49.298065    34.563517
# std       4.884599     5.900935     3.422136     3.288265     2.742323
# min      21.600000    21.800000    37.700000    37.700000    25.200000
# 25%      31.700000    31.200000    46.900000    47.100000    32.600000
# 50%      34.900000    34.900000    49.000000    49.300000    34.600000
# 75%      38.300000    39.200000    51.400000    51.500000    36.400000
# max      51.000000    58.500000    62.600000    61.200000    44.100000
#
#               3P_D        ADJ_T          WAB        SEED         YEAR
# count  1757.000000  1757.000000  1757.000000  340.000000  1757.000000
# mean     34.744792    68.422254    -7.837109    8.791176  2017.002277
# std       2.369727     3.258920     6.988694    4.674090     1.415419
# min      27.100000    57.200000   -25.200000    1.000000  2015.000000
# 25%      33.100000    66.400000   -13.000000    5.000000  2016.000000
# 50%      34.700000    68.500000    -8.400000    9.000000  2017.000000
# 75%      36.300000    70.400000    -3.100000   13.000000  2018.000000
# max      43.100000    83.400000    13.100000   16.000000  2019.000000
#
# [8 rows x 21 columns]

# %%
data.corr()
# Out:
#                 G         W     ADJOE     ADJDE   BARTHAG     EFG_O     EFG_D  \
# G        1.000000  0.708838  0.613432 -0.606166  0.688059  0.346425 -0.481942
# W        0.708838  1.000000  0.754532 -0.690753  0.814512  0.617839 -0.609144
# ADJOE    0.613432  0.754532  1.000000 -0.528576  0.870686  0.732683 -0.333693
# ADJDE   -0.606166 -0.690753 -0.528576  1.000000 -0.852432 -0.221381  0.792320
# BARTHAG  0.688059  0.814512  0.870686 -0.852432  1.000000  0.543153 -0.627696
# EFG_O    0.346425  0.617839  0.732683 -0.221381  0.543153  1.000000 -0.120335
# EFG_D   -0.481942 -0.609144 -0.333693  0.792320 -0.627696 -0.120335  1.000000
# TOR     -0.336407 -0.467073 -0.601024  0.219779 -0.472329 -0.367975  0.101070
# G       -0.439340  0.225821 -0.349726 -0.040433  0.666595 -0.607807  0.052233
# W       -0.529558  0.432743 -0.485485 -0.016057  0.905029 -0.612284  0.091829
# ADJOE   -0.328822  0.579193 -0.198275  0.070476  0.851663 -0.791692  0.048861
# ADJDE    0.728488 -0.102715  0.564135  0.227852 -0.809486  0.706046  0.055367
# BARTHAG -0.588121  0.386597 -0.427750 -0.079611  0.941776 -0.832709  0.000228
# EFG_O   -0.104079  0.763028 -0.100545  0.120142  0.562904 -0.275137  0.196195
# EFG_D    0.907933 -0.043770  0.722404  0.273412 -0.629864  0.386928  0.211657
# TOR      0.091686 -0.333397  0.066363 -0.102687 -0.470286  0.291587 -0.054840
# TORD     0.027203 -0.177276 -0.106798 -0.065216  0.094765  0.057411 -0.051754
# ORB     -0.341291 -0.143735 -0.197189 -0.105308  0.332275 -0.314659 -0.217610
# DRB      0.183057 -0.225528  0.090050  0.032497 -0.303666  0.114416 -0.297920
# FTR     -0.202888 -0.093085 -0.108273  0.039090  0.146079  0.091152 -0.326780
# FTRD     0.088794 -0.267869  0.103091 -0.000793 -0.333798  0.250020 -0.273743
# 2P_O    -0.119930  0.402768 -0.138731  0.163304  0.530586 -0.235655  0.245197
# 2P_D     1.000000 -0.053283  0.373182  0.283103 -0.574111  0.391802  0.253167
# 3P_O    -0.053283  1.000000 -0.009907  0.017151  0.403304 -0.220968  0.034529
# 3P_D     0.373182 -0.009907  1.000000  0.141897 -0.455148  0.157616  0.024843
# ADJ_T    0.283103  0.017151  0.141897  1.000000 -0.056011  0.043924  0.380953
# WAB     -0.574111  0.403304 -0.455148 -0.056011  1.000000 -0.922111 -0.003705
# SEED     0.391802 -0.220968  0.157616  0.043924 -0.922111  1.000000  0.000446
# YEAR     0.253167  0.034529  0.024843  0.380953 -0.003705  0.000446  1.000000
#
# [21 rows x 21 columns]

# %%
pd.plotting.scatter_matrix(data[['CONF', 'G', 'W', 'ADJOE', 'BARTHAG']], alpha=.01, figsize=(10, 10))
pass

# %%
pd.plotting.scatter_matrix(data[['CONF', 'G', 'W', 'ADJOE', 'BARTHAG']], figsize=(10, 10))
pass

# %%
plt.plot(data['ADJOE'], data['BARTHAG'], 'o')
plt.xlabel('ADJOE image band')
plt.ylabel('BARTHAG image band')
plt.title('Test')
pass

# %%
data['ADJOE'] < 115
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1752     True
# 1753    False
# 1754    False
# 1755    False
# 1756    False
# Name: ADJOE, Length: 1757, dtype: bool

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data[data['BARTHAG'] >=0.5]['G'],
            data[data['BARTHAG'] >=0.5]['W'],
            alpha = 1,
            label = '>=1',
            color = 'b')

plt.scatter(data[data['BARTHAG'] < 0.5]['G'],
            data[data['BARTHAG'] < 0.5]['W'],
            alpha = 1,
            label = '< 1',
            color = 'r')

plt.xlabel('Games')
plt.xticks(range(100))
plt.xlim(0, 100)
plt.ylabel('Wins')
plt.legend()
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#                     TEAM  CONF POSTSEASON
# count               1757  1757        340
# unique               355    33          8
# top     SIU Edwardsville   ACC        R64
# freq                   5    75        160

# %% [markdown]
# # Нормализация

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(data.TEAM)
data['TEAM'] = le.transform(data.TEAM)

le.fit(data.CONF)
data['CONF'] = le.transform(data.CONF)

del data['POSTSEASON']
data
# Out:
#       TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 0      200     1  40  33  123.3   94.9   0.9531   52.6   48.1  15.4  ...
# 1      348     5  40  36  129.1   93.6   0.9758   54.8   47.7  12.4  ...
# 2      170     5  40  33  114.4   90.4   0.9375   53.9   47.7  14.0  ...
# 3      297     6  38  31  115.2   85.2   0.9696   53.5   43.0  17.7  ...
# 4      103    32  39  37  117.8   86.3   0.9728   56.6   41.1  16.2  ...
# ...    ...   ...  ..  ..    ...    ...      ...    ...    ...   ...  ...
# 1752   293    27  35  22  111.2   94.7   0.8640   51.4   46.9  19.2  ...
# 1753   140    27  35  28  117.9   96.6   0.9081   51.2   49.9  17.9  ...
# 1754   288    27  36  31  122.8   95.2   0.9488   55.3   48.1  15.8  ...
# 1755   103    32  35  27  117.4   94.5   0.9238   55.2   44.8  17.1  ...
# 1756   103    32  37  32  117.2   94.9   0.9192   57.0   47.1  16.1  ...
#
#        FTR  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  SEED  YEAR
# 0     32.3  30.4  53.9  44.6  32.7  36.2   71.7   8.6   1.0  2016
# 1     36.2  22.4  54.8  44.7  36.5  37.5   59.3  11.3   1.0  2015
# 2     30.7  30.0  54.7  46.8  35.2  33.2   65.9   6.9   3.0  2018
# 3     32.9  36.6  52.8  41.9  36.5  29.7   67.5   7.0   3.0  2019
# 4     39.0  26.9  56.3  40.0  38.2  29.0   71.5   7.7   1.0  2017
# ...    ...   ...   ...   ...   ...   ...    ...   ...   ...   ...
# 1752  32.0  27.6  52.5  45.7  32.9  32.6   70.3   1.9   7.0  2018
# 1753  37.1  33.1  52.9  49.4  31.9  33.7   71.2   7.3   3.0  2019
# 1754  33.3  34.9  55.4  44.7  36.7  35.4   68.8   9.9   2.0  2019
# 1755  34.4  28.1  54.3  44.4  37.8  30.3   68.2   2.1  11.0  2016
# 1756  32.1  29.1  58.2  44.1  36.8  35.0   70.5   4.9   4.0  2018
#
# [1757 rows x 23 columns]

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# []
# ['TEAM', 'CONF', 'G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D', 'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O', '3P_D', 'ADJ_T', 'WAB', 'SEED', 'YEAR']

# %%
data.median(axis = 0)
# Out:
# TEAM        178.000
# CONF         16.000
# G            31.000
# W            16.000
# ADJOE       103.100
# ADJDE       103.800
# BARTHAG       0.474
# EFG_O        50.000
# EFG_D        50.300
# TOR          18.500
# TORD         18.500
# ORB          29.400
# DRB          29.400
# FTR          34.900
# FTRD         34.900
# 2P_O         49.000
# 2P_D         49.300
# 3P_O         34.600
# 3P_D         34.700
# ADJ_T        68.500
# WAB          -8.400
# SEED          9.000
# YEAR       2017.000
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# [] []

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#               TEAM         CONF            G            W        ADJOE  \
# count  1757.000000  1757.000000  1757.000000  1757.000000  1757.000000
# mean    177.786568    15.770063    31.523051    16.513375   103.542402
# std     102.501828     9.692690     2.602819     6.545571     7.304975
# min       0.000000     0.000000    24.000000     0.000000    76.700000
# 25%      89.000000     7.000000    30.000000    12.000000    98.600000
# 50%     178.000000    16.000000    31.000000    16.000000   103.100000
# 75%     267.000000    24.000000    33.000000    21.000000   108.100000
# max     354.000000    32.000000    40.000000    38.000000   129.100000
#
#              ADJDE      BARTHAG        EFG_O        EFG_D          TOR  ...  \
# count  1757.000000  1757.000000  1757.000000  1757.000000  1757.000
1.757000e+03  1.757000e+03  1.757000e+03  1.757000e+03  1.757000e+03
# mean  -3.498119e-15 -1.337568e-15  3.711886e-15 -4.423199e-18  7.408227e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.414447e+00 -3.226022e+00 -3.443550e+00 -2.484426e+00 -3.872627e+00
# 25%   -7.160051e-01 -6.940851e-01 -6.205289e-01 -7.387491e-01  1.966082e-02
# 50%    1.330355e-02 -1.890186e-02  2.385642e-02 -8.054313e-02  1.966082e-02
# 75%    6.696813e-01  6.562814e-01  6.068717e-01  6.778246e-01  1.966082e-02
# max    3.477520e+00  3.525810e+00  4.595924e+00  2.995854e+00  3.425413e+00
#
#                YEAR
# count  1.757000e+03
# mean  -4.134263e-14
# std    1.000000e+00
# min   -1.414617e+00
# 25%   -7.081129e-01
# 50%   -1.608434e-03
# 75%    7.048960e-01
# max    1.411400e+00
#
# [8 rows x 23 columns]

# %% [markdown]
# # X & Y

# %%
X = data.drop(('BARTHAG'), axis = 1)
y = data['BARTHAG']
feature_names = X.columns

# %%
from sklearn.preprocessing import Imputer 
imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0) 
imputer.fit(X)  
X = imputer.transform(X)
# Out:
# C:\Users\Maxim\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (1757, 22)
# (1757,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 1229 528

# %%
from sklearn import utils

print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
# Out:
# continuous
# multiclass

# %% [markdown]
# # kNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, y_train.astype('int'))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train.astype("int") != y_train_predict)
err_test  = np.mean(y_test.astype("int")  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.10252237591537836 0.13825757575757575

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train.astype('int'))

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.15052888527257935 5

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != knn.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.10252237591537836 0.13825757575757575

# %% [markdown]
# # Ensemble

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != rf.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.056818181818181816

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature '  WAB' (0.219003)
#  2. feature 'ADJOE' (0.196867)
#  3. feature 'ADJDE' (0.162438)
#  4. feature '    W' (0.060879)
#  5. feature ' SEED' (0.040177)
#  6. feature '    G' (0.036526)
#  7. feature 'EFG_D' (0.029587)
#  8. feature ' 2P_D' (0.027076)
#  9. feature 'EFG_O' (0.026133)
# 10. feature '  DRB' (0.023760)
# 11. feature '  TOR' (0.022830)
# 12. feature ' CONF' (0.022314)
# 13. feature ' 2P_O' (0.019873)
# 14. feature ' 3P_O' (0.015772)
# 15. feature ' 3P_D' (0.015084)
# 16. feature '  ORB' (0.014164)
# 17. feature ' FTRD' (0.013146)
# 18. feature ' TORD' (0.013017)
# 19. feature 'ADJ_T' (0.013006)
# 20. feature ' TEAM' (0.012309)
# 21. feature '  FTR' (0.011409)
# 22. feature ' YEAR' (0.004629)

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature '  WAB' (0.219003)
#  2. feature 'ADJOE' (0.196867)
#  3. feature 'ADJDE' (0.162438)
#  4. feature '    W' (0.060879)
#  5. feature ' SEED' (0.040177)
#  6. feature '    G' (0.036526)
#  7. feature 'EFG_D' (0.029587)
#  8. feature ' 2P_D' (0.027076)
#  9. feature 'EFG_O' (0.026133)
# 10. feature '  DRB' (0.023760)
# 11. feature '  TOR' (0.022830)
# 12. feature ' CONF' (0.022314)
# 13. feature ' 2P_O' (0.019873)
# 14. feature ' 3P_O' (0.015772)
# 15. feature ' 3P_D' (0.015084)
# 16. feature '  ORB' (0.014164)
# 17. feature ' FTRD' (0.013146)
# 18. feature ' TORD' (0.013017)
# 19. feature 'ADJ_T' (0.013006)
# 20. feature ' TEAM' (0.012309)
# 21. feature '  FTR' (0.011409)
# 22. feature ' YEAR' (0.004629)

# %%
feature_names[[1,0,1]]
# Out:
# Index(['CONF', 'TEAM', 'CONF'], dtype='object')

# %%
d_first = 20
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'b')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 20)

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != ert.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.05303030303030303

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != ada.predict(X_train))
err_test = np.mean(y_test.astype('int') != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.1562245728234337 0.17803030303030304

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != gbt.predict(X_train))
err_test = np.mean(y_test.astype('int') != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.041666666666666664

# %% [markdown]
# # Нейронные сети

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape
y_train = y_train.astype("int")
y_test = y_test.astype("int")

# %%
from sklearn.neural_network import MLPClassifier


mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=42, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %%
# Ошибка на тестовой и обучающей выборке
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.0 0.05517241379310345

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'test')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'train')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.02586206896551724

# %%
# Оптимальное значение alpha: 
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
# Out:
# [0.03162278]

# %%
alpha_opt = alpha_opt[0]

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (100,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.0
# 0.02586206896551724

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test_pred, y_test))
# Out:
# [[ 88   4   0]
#  [  3 349   4]
#  [  0   4 128]]

# %%
M = confusion_matrix(y_test_pred, y_test)
M = np.sqrt(M)
plt.imshow(M, interpolation = 'nearest')
plt.set_cmap('binary')
plt.xticks(range(10))
plt.yticks(range(10))
plt.xlabel("true label")
plt.ylabel("predicted label")
plt.colorbar()
pass

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (2,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.015517241379310345

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
# Out:
# [0.001]

# %%
alpha_opt = alpha_opt[0]

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (2,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.0
# 0.015517241379310345

# %%
layer_sizes_arr = np.arange(2, 40, 1)
test_err = []
train_err = []
for layer_sizes in layer_sizes_arr:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (layer_sizes,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.plot(layer_sizes_arr, train_err, 'b-o', label = 'train')
plt.plot(layer_sizes_arr, test_err, 'r-o', label = 'test')
plt.title('Error vs. number of neurons')
plt.xlabel('Number of neurons')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

layer_opt = layer_sizes_arr[test_err == min_test_err]
print("Оптимальное число нейронов:{}".format(layer_opt))
# Out:
# 0.0 0.015517241379310345
# Оптимальное число нейронов:[2]

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(n_estimators=100, random_state=42, oob_score=True)
RFC.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=True, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_train_pred = RFC.predict(X_train)
y_test_pred = RFC.predict(X_test)

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.0 0.07241379310344828

# %%
est_arr = np.arange(16, 101, 5)
test_err = []
train_err = []
oob_err = []
RFC = RandomForestClassifier(warm_start=True, n_estimators=1, random_state=42, oob_score=True)
for est in est_arr:
    RFC.set_params(n_estimators=est)
    RFC.fit(X_train, y_train)

    y_train_pred = RFC.predict(X_train)
    y_test_pred = RFC.predict(X_test)
    
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    oob_err.append(1 - RFC.oob_score_)
# Out:
# C:\Users\Maxim\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\Maxim\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %%
plt.plot(est_arr, train_err, 'b-o', label = 'train')
plt.plot(est_arr, test_err, 'r-o', label = 'test')
plt.plot(est_arr, oob_err, 'g-o', label = 'oob')
#plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('Number of trees')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
min_oob_error = np.min(oob_err)
print(min_train_err, min_test_err, min_oob_error)

# Оптимальное количество деревьев:
est_opt = est_arr[test_err == min_test_err]
print("Оптимальное число деревьев:{}".format(est_opt))

# Минимум oob ошибки достигается при количестве деревьев:
oob_opt = est_arr[oob_err == min_oob_error]
print("Минимум oob ошибки при числе деревьев:{}".format(oob_opt))
# Out:
# 0.0 0.06896551724137931 0.06881903143585388
# Оптимальное число деревьев:[51]
# Минимум oob ошибки при числе деревьев:[71]

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier(n_estimators=100, random_state=42)
GBC.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=42, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
y_train_pred = GBC.predict(X_train)
y_test_pred = GBC.predict(X_test)

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.0 0.041379310344827586

# %%
est_arr = np.arange(16, 101, 5)
test_err = []
train_err = []
GBC = GradientBoostingClassifier(n_estimators=1, random_state=42)
for est in est_arr:
    GBC.set_params(n_estimators=est)
    GBC.fit(X_train, y_train)

    y_train_pred = GBC.predict(X_train)
    y_test_pred = GBC.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.plot(est_arr, train_err, 'b-o', label = 'train')
plt.plot(est_arr, test_err, 'r-o', label = 'test')
#plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('Number of trees')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)


# Оптимальное количество деревьев:
est_opt = est_arr[test_err == min_test_err]
print("Оптимальное число деревьев:{}".format(est_opt))
# Out:
# 0.0 0.03620689655172414
# Оптимальное число деревьев:[66]
